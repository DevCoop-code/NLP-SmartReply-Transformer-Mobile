# %%
pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 6.0 MB/s
# ...
#      |████████████████████████████████| 453 kB 66.9 MB/s
# ...

# %%
from preprocess import *

PATH = 'data_in/ChatbotData.csv'
VOCAB_PATH = 'data_in/vocabulary.txt'

inputs, outputs = load_data(PATH)
char2idx, idx2char, vocab_size = load_vocabulary(PATH, VOCAB_PATH)

# %%
# Model에 학습할 인덱스 데이터를 구성
index_inputs, input_seq_len = enc_processing(inputs, char2idx, tokenize_as_morph=False)
index_outputs, output_seq_len = dec_output_processing(outputs, char2idx, tokenize_as_morph=False)
index_targets = dec_target_processing(outputs, char2idx, tokenize_as_morph=False)

# %%
# Model에 학습할 인덱스 데이터를 구성
data_configs = {}
data_configs['char2idx'] = char2idx          # character to id dictionary
data_configs['idx2char'] = idx2char          # id to character dictionary
data_configs['vocab_size'] = vocab_size
data_configs['pad_symbol'] = PAD
data_configs['std_symbol'] = STD
data_configs['end_symbol'] = END
data_configs['unk_symbol'] = UNK

# %%
DATA_IN_PATH = './data_in/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

# Model에서 사용할 Index Data
np.save(open(DATA_IN_PATH + TRAIN_INPUTS, 'wb'), index_inputs)
np.save(open(DATA_IN_PATH + TRAIN_OUTPUTS, 'wb'), index_outputs)
np.save(open(DATA_IN_PATH + TRAIN_TARGETS, 'wb'), index_targets)

# 단어사전을 구성한 Dictionary
json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'))

# %%
char2idx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ffd3c870fb0a> in <module>()
# ----> 1 char2idx
#
# NameError: name 'char2idx' is not defined

# %%
idx2char
# Out:
# {0: '<PAD>',
#  1: '<SOS>',
#  2: '<END>',
#  3: '<UNK>',
#  4: '나',
#  5: '좋을까',
#  6: '승진',
#  7: '같아',
#  8: '해',
#  9: '자의',
#  10: '좀',
#  11: '거예요',
#  12: '빠를수록',
#  13: '오늘',
#  14: '땀을',
#  15: '사세요',
#  16: '선물로',
#  17: '가끔은',
#  18: '어서',
#  19: '혼자인게',
#  20: '끄고',
#  21: '좋다',
#  22: '나라를',
#  23: '더',
#  24: '즐기세요',
#  25: '남자친구가',
#  26: '따라',
#  27: '질린다',
#  28: '평소에',
#  29: '게',
#  30: '해보세요',
#  31: '나온거',
#  32: '나오세요',
#  33: '좋을',
#  34: '함께',
#  35: '마음을',
#  36: '새출발',
#  37: '따뜻하게',
#  38: '설득해보세요',
#  39: '절약해봐요',
#  40: '결단은',
#  41: '가스불',
#  42: '망함',
#  43: '좋아요',
#  44: '갔어',
#  45: '비싼데',
#  46: '설움',
#  47: '보인다',
#  48: '뭘',
#  49: '데려가고',
#  50: '켜놓고',
#  51: '가상화폐',
#  52: '것',
#  53: '나왔다',
#  54: '운동',
#  55: '전생에',
#  56: '열',
#  57: '구하셨나요',
#  58: '교회',
#  59: '가난한',
#  60: '사람도',
#  61: '싶어',
#  62: '가끔',
#  63: '뭐가',
#  64: '거짓말',
#  65: '달에는',
#  66: '땀난다',
#  67: '그럴',
#  68: '쫄딱',
#  69: '안',
#  70: '걸리겠어',
#  71: '생각해보세요',
# ...

# %% [markdown]
# # **Convert data_configs.json to utf8 format**

# %%
import json

# For using Mobile
with open('data_configs.json', 'r', encoding='utf8') as f:
  json_data = json.load(f)

# print(json.dumps(json_data))

json.dump(json.dumps(json_data, ensure_ascii=False), open('./data_in/' + 'vectoword.json', 'w', encoding='utf8'), ensure_ascii=False)
